# %% [markdown]
# # 🐍 Advanced: Advanced OOP
#
# ---

# %% [markdown]
# ## 🏗️ Inheritance

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return f"{self.name} says Woof!"

class Cat(Animal):
    def speak(self):
        return f"{self.name} says Meow!"

dog = Dog("Buddy")
print(dog.speak())

# %% [markdown]
# ## 🎓 Key Takeaways
# ✅ Inheritance for code reuse
# ✅ `super()` calls parent methods
# ✅ Polymorphism allows flexibility
