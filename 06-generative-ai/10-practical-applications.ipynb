# %% [markdown]
# # 🌟 GenAI: Applications
#
# ## Real-World AI
#
# 1. Document Q&A with RAG
# 2. AI Agents
# 3. Chatbots
# 4. Code assistants
#
# ## 🎉 Course Complete!
# 37 notebooks: Basics to GenAI with RAG, Agents, MCP!
